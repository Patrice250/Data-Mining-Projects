# %%
text1 = "Ethics are built right into the ideals and objectives of the United Nations"

# %%
len(text1)
# Out:
# 75

# %%
text2 = text1.split(' ')

# %%
text2
# Out:
# ['Ethics',
#  'are',
#  'built',
#  'right',
#  'into',
#  'the',
#  'ideals',
#  'and',
#  'objectives',
#  'of',
#  'the',
#  'United',
#  'Nations']

# %%
len(text2)
# Out:
# 13

# %%
[w for w in text2 if len(w)>3]
# Out:
# ['Ethics',
#  'built',
#  'right',
#  'into',
#  'ideals',
#  'objectives',
#  'United',
#  'Nations']

# %%
# Capitalized words
[w for w in text2 if w.istitle()]
# Out:
# ['Ethics', 'United', 'Nations']

# %%
# words that end with s 
[w for w in text2 if w.endswith('s')]
# Out:
# ['Ethics', 'ideals', 'objectives', 'Nations']

# %%
text3 = 'To be or not to be' # findind unique words
text4  =  text3.split(' ')

# %%
text4
# Out:
# ['To', 'be', 'or', 'not', 'to', 'be']

# %%
len(text4)
# Out:
# 6

# %%
len(set(text4))
# Out:
# 5

# %%
set(text4)
# Out:
# {'To', 'be', 'not', 'or', 'to'}

# %%
len(set([w.lower() for w in text4]))
# Out:
# 4

# %%
set([w.lower() for w in text4 ])
# Out:
# {'be', 'not', 'or', 'to'}

# %%
# some words comparison functions..
# s.startswith(t)
#s.endswith(t)
# t in s
# s.isupper() ; s.islower(); s.istitle()
# s.isalpha( ); s.isdigit(); s.isalnum()

# %%
# string Operation 
# s.lower()
# s.upper();
# s.titlecase();
# s.split(t)
# s.splitlines()
# s.join(t)
# s.strip()
# s.rstrip()
# s.find(t); s.rfind(t)
# s.replace(u,v)

# %%
text5 = 'ouagadougou'
text6= text5.split('ou')

# %%
text6
# Out:
# ['', 'agad', 'g', '']

# %%
'ou'.join(text6)
# Out:
# 'ouagadougou'

# %%
list(text5)
# Out:
# ['o', 'u', 'a', 'g', 'a', 'd', 'o', 'u', 'g', 'o', 'u']

# %%
[c for c in text5]
# Out:
# ['o', 'u', 'a', 'g', 'a', 'd', 'o', 'u', 'g', 'o', 'u']

# %%
text8 = '   A quick brown fox jumped over the lazy dog.  '

# %%
text8.split(' ')
# Out:
# ['',
#  '',
#  '',
#  'A',
#  'quick',
#  'brown',
#  'fox',
#  'jumped',
#  'over',
#  'the',
#  'lazy',
#  'dog.',
#  '',
#  '']

# %%
text9 = text8.strip()

# %%
text9
# Out:
# 'A quick brown fox jumped over the lazy dog.'

# %%
text9.split(' ')
# Out:
# ['A', 'quick', 'brown', 'fox', 'jumped', 'over', 'the', 'lazy', 'dog.']

# %%
# changing text
# Find and replace
text9
# Out:
# 'A quick brown fox jumped over the lazy dog.'

# %%
text9.find('o')
# Out:
# 10

# %%
text9.rfind('o')
# Out:
# 40

# %%
text9.replace('o', 'O')
# Out:
# 'A quick brOwn fOx jumped Over the lazy dOg.'

# %%
# handling large texts
f=open('QUESTION 1.docx', 'r')

# %%
# !pip install python-docx
# Out:
# Requirement already satisfied: python-docx in c:\users\tuyiz\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\tuyiz\anaconda3\lib\site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\tuyiz\anaconda3\lib\site-packages (from python-docx) (4.11.0)

# %%
from docx import Document

# Load the DOCX file
doc = Document('QUESTION 1.docx')

# Loop through paragraphs and print the text
for para in doc.paragraphs:
    print(para.text)
# Out:
# The embedded systems which specifically refer to small, portable embedded devices like cellphones, laptops, and calculators, are known as Mobile Embedded Systems.The embedded system in which the violation of time limitations will cause only degraded quality, but the system can continue to operate is known as Soft Real-Time System.An embedded system in which a missed deadline doesn't degrade system performance is known as firm Real-Time System.An embedded system that does not require any host system for its functioning and can control and drive attached devices while producing outputs independently is known as Standalone Embedded System.An embedded system in which the violation of time constraints will cause critical failure and loss of life or property damage or catastrophe is known as Hard Real-Time System.

# %%
f.readline()# reading line by line
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 f.readline()
#
# ValueError: I/O operation on closed file.

# %%
# reading the full file 
f.seek(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[95], line 2
#       1 # reading the full file
# ----> 2 f.para.text(0)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'para'

# %%
text12= f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 text13= f.read()
#
# ValueError: I/O operation on closed file.

# %%
text12
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 text12
#
# NameError: name 'text12' is not defined

# %%
len(text12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 len(text12)
#
# NameError: name 'text12' is not defined

# %%
text13 = para.text.splitlines()
text13
# Out:
# ["The embedded systems which specifically refer to small, portable embedded devices like cellphones, laptops, and calculators, are known as Mobile Embedded Systems.The embedded system in which the violation of time limitations will cause only degraded quality, but the system can continue to operate is known as Soft Real-Time System.An embedded system in which a missed deadline doesn't degrade system performance is known as firm Real-Time System.An embedded system that does not require any host system for its functioning and can control and drive attached devices while producing outputs independently is known as Standalone Embedded System.An embedded system in which the violation of time constraints will cause critical failure and loss of life or property damage or catastrophe is known as Hard Real-Time System."]

# %%
len(para.text)
# Out:
# 819

# %%
text13[0]
# Out:
# "The embedded systems which specifically refer to small, portable embedded devices like cellphones, laptops, and calculators, are known as Mobile Embedded Systems.The embedded system in which the violation of time limitations will cause only degraded quality, but the system can continue to operate is known as Soft Real-Time System.An embedded system in which a missed deadline doesn't degrade system performance is known as firm Real-Time System.An embedded system that does not require any host system for its functioning and can control and drive attached devices while producing outputs independently is known as Standalone Embedded System.An embedded system in which the violation of time constraints will cause critical failure and loss of life or property damage or catastrophe is known as Hard Real-Time System."

# %%
# file operatios 
# f= open(filename,  mode)
# f.readlie();f.read(); f.read(n)
# for line in f: doSomething(line)
# f.seek()
# f.write(message)
# f.close()
# f.closed

# %%
f = open('C:\\Users\\ujjwal\\Desktop\\docker.txt', 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 f = open('C:\\Users\\ujjwal\\Desktop\\docker.txt', 'r')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\ujjwal\\Desktop\\docker.txt'

# %%
text14 = f.readline()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 text14 = f.readline()
#
# NameError: name 'f' is not defined

# %%
text14 # issues with reading text files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 text14
#
# NameError: name 'text14' is not defined

# %%
# how do you remove the last newline character ?
text14.rstrip()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 # how do you remove the last newline character ?
# ----> 2 text14.rstrip()
#
# NameError: name 'text14' is not defined

# %%
# Processing free-text
text15 = '"Ethics are built right into the ideals and objectives of the United Nations" \
#UNSG @ NY Society for Ethical Culture bit.ly/2guVelr'

# %%
text16 = text13.split(' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 text16 = text13.split(' ')
#
# AttributeError: 'list' object has no attribute 'split'

# %%
text16
# Out:
# ['"Ethics',
#  'are',
#  'built',
#  'right',
#  'into',
#  'the',
#  'ideals',
#  'and',
#  'objectives',
#  'of',
#  'the',
#  'United',
#  'Nations"',
#  '#UNSG',
#  '@',
#  'NY',
#  'Society',
#  'for',
#  'Ethical',
#  'Culture',
#  'bit.ly/2guVelr']

# %%
[w for w in text16 if w.startswith('#')] # fiding hastags
# Out:
# ['#UNSG']

# %%
[w for w in text16 if w.startswith('@')]
# Out:
# ['@']

# %%
text17 = '@UN @UN_Women "Ethics are built right into the ideals and objectives of the United Nations" \#UNSG @ NY Society for Ethical Culture bit.ly/2guVelr'
text18 = text17.split(' ')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\#'
# <>:1: SyntaxWarning: invalid escape sequence '\#'
# C:\Users\tuyiz\AppData\Local\Temp\ipykernel_30924\3375942933.py:1: SyntaxWarning: invalid escape sequence '\#'
#   text17 = '@UN @UN_Women "Ethics are built right into the ideals and objectives of the United Nations" \#UNSG @ NY Society for Ethical Culture bit.ly/2guVelr'

# %%
text18
# Out:
# ['@UN',
#  '@UN_Women',
#  '"Ethics',
#  'are',
#  'built',
#  'right',
#  'into',
#  'the',
#  'ideals',
#  'and',
#  'objectives',
#  'of',
#  'the',
#  'United',
#  'Nations"',
#  '\\#UNSG',
#  '@',
#  'NY',
#  'Society',
#  'for',
#  'Ethical',
#  'Culture',
#  'bit.ly/2guVelr']

# %%
#We can use regular expressions to help us with more complex parsing.

#For example '@[A-Za-z0-9_]+' will return all words that:

#start with '@' and are followed by at least one:
#capital letter ('A-Z')
#lowercase letter ('a-z')
#number ('0-9')
#or underscore ('_')

# %%
#import re  # import re - a module that provides support for regular expressions
#[w for w in text18 if re.search('@[A-Za-z0-9_]+',w)]



########## 
#######  Meta-chacters: Character matches

#  . "wildcaard, matches a single character" 
#  ^ "start of a string"
# $ "end of a string"
# [] "matches one of the set of character within []"
# [a-z] "matches one of the range of chacarters a,b,c,....z"
# [^abc] "matches a character that is not a,b, or c "
# a|b "matches either a or  b, where a and b are strings"
# () "Scoping for opertors"
# \ "Escape character for special character (\t,\n,\b)"

########## 
#######  Meta-chacters: Character symbols

#  \b "matches word boundary"
#  \d "any digit, equivalent to [0-9]"
#   \D "any non-digit, equivalent to [^0-9]"
#  \s "any white space, equivalent to [ \t \n \r \f \v]"
#  \S "any non-white space, equivalent to[^ \t\n\r\f\v]"
# \w "Alphaumeric character , equivalent to[a-zA-Z0-9_]"
# \W " non-alphanumeric, equivalent to[^a-zA-Z0-9_]"


########## 
#######  Meta-chacters: Repetitios

# * "matches zero or more occurreces"
# + " MATCHES one or more occurrences"
# ? "Matches zero or more occurrences"
# {n} "exactly n repetitions"
# {n,} "at least n repetitions"
# {,n} " at most n repetitions"
# {m,n} "at least m and at most n repetitions"

#[w for w in text18 if re.search('@\w+' , w)]

# %%
#finding special charcter 
import re
text20 = 'ousnduiuela'
re.findall(r'[aeiou]',text20)
# Out:
# ['o', 'u', 'u', 'i', 'u', 'e', 'a']

# %%
re.findall(r'[^aeiou]',text20)
# Out:
# ['s', 'n', 'd', 'l']

# %%
#regular expression for  dates
dateStr = '23-10-2002\n23/10/2002\n23/10/02\n10/23/2002\n23 Oct 2002\n23 October 2002\nOct 23,2002\nOctober 23,2002\n'

# %%
re.findall(r'\d{2}[/-]\d{2}[/-]\d{4}',dateStr)
# Out:
# ['23-10-2002', '23/10/2002', '10/23/2002']

# %%
re.findall(r'\d{2}[/-]\d{2}[/-]\d{2,4}',dateStr)
# Out:
# ['23-10-2002', '23/10/2002', '23/10/02', '10/23/2002']

# %%
re.findall(r'\d{1,2}[/-]\d{1,2}[/-]\d{2,4}',dateStr)
# Out:
# ['23-10-2002', '23/10/2002', '23/10/02', '10/23/2002']

# %%
#Regex for Dates(Contd.)
re.findall(r'\d{2} (Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec) \d{4}',dateStr)
# Out:
# ['Oct']

# %%
re.findall(r'\d{2} (?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec) \d{4}',dateStr)
# Out:
# ['23 Oct 2002']

# %%
re.findall(r'\d{2} (?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]* \d{4}',dateStr)
# Out:
# ['23 Oct 2002', '23 October 2002']

# %%
re.findall(r'(?:\d{2} )?(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]* (?:\d{2},)?\d{4}', dateStr)
# Out:
# ['23 Oct 2002', '23 October 2002', 'Oct 23,2002', 'October 23,2002']

# %%
re.findall(r'(?:\d{1,2} )?(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]* (?:\d{1,2},)?\d{4}', dateStr)
# Out:
# ['23 Oct 2002', '23 October 2002', 'Oct 23,2002', 'October 23,2002']

# %%
#Working with Text Data in pandas

import pandas as pd

# %%
time_sentences = ["Monday: The doctor's appointment is at 2:45pm.", 
                  "Tuesday: The dentist's appointment is at 11:30 am.",
                  "Wednesday: At 7:00pm, there is a basketball game!",
                  "Thursday: Be back home by 11:15 pm at the latest.",
                  "Friday: Take the train at 08:10 am, arrive at 09:00am."]

df = pd.DataFrame(time_sentences, columns=['text'])
df
# Out:
#                                                 text
# 0     Monday: The doctor's appointment is at 2:45pm.
# 1  Tuesday: The dentist's appointment is at 11:30...
# 2  Wednesday: At 7:00pm, there is a basketball game!
# 3  Thursday: Be back home by 11:15 pm at the latest.
# 4  Friday: Take the train at 08:10 am, arrive at ...

# %%
# find the number of characters for each string in df['text']
df['text'].str.len()
# Out:
# 0    46
# 1    50
# 2    49
# 3    49
# 4    54
# Name: text, dtype: int64

# %%
# find the number of tokens for each string in df['text']
df['text'].str.split().str.len()
# Out:
# 0     7
# 1     8
# 2     8
# 3    10
# 4    10
# Name: text, dtype: int64

# %%
# find which entries contain the word 'appointment'
df['text'].str.contains('appointment')
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: text, dtype: bool

# %%
# find how many times a digit occurs in each string
df['text'].str.count(r'\d')
# Out:
# 0    3
# 1    4
# 2    3
# 3    4
# 4    8
# Name: text, dtype: int64

# %%
# find all occurances of the digits
df['text'].str.findall(r'\d')
# Out:
# 0                   [2, 4, 5]
# 1                [1, 1, 3, 0]
# 2                   [7, 0, 0]
# 3                [1, 1, 1, 5]
# 4    [0, 8, 1, 0, 0, 9, 0, 0]
# Name: text, dtype: object

# %%
# group and find the hours and minutes
df['text'].str.findall(r'(\d?\d):(\d\d)')
# Out:
# 0               [(2, 45)]
# 1              [(11, 30)]
# 2               [(7, 00)]
# 3              [(11, 15)]
# 4    [(08, 10), (09, 00)]
# Name: text, dtype: object

# %%
# replace weekdays with '???'
df['text'].str.replace(r'\w+day\b', '???')
# Out:
# 0       Monday: The doctor's appointment is at 2:45pm.
# 1    Tuesday: The dentist's appointment is at 11:30...
# 2    Wednesday: At 7:00pm, there is a basketball game!
# 3    Thursday: Be back home by 11:15 pm at the latest.
# 4    Friday: Take the train at 08:10 am, arrive at ...
# Name: text, dtype: object

# %%
# replace weekdays with 3 letter abbrevations
df['text'].str.replace(r'(\w+day\b)', lambda x: x.groups()[0][:3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 2
#       1 # replace weekdays with 3 letter abbrevations
# ----> 2 df['text'].str.replace(r'(\w+day\b)', lambda x: x.groups()[0][:3])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:1562, in StringMethods.replace(self, pat, repl, n, case, flags, regex)
#    1558     raise ValueError(
#    1559         "Cannot use a compiled regex as replacement pattern with regex=False"
#    1560     )
#    1561 elif callable(repl):
# -> 1562     raise ValueError("Cannot use a callable replacement when regex=False")
#    1564 if case is None:
#    1565     case = True
#
# ValueError: Cannot use a callable replacement when regex=False

# %%
# create new columns from first match of extracted groups
df['text'].str.extract(r'(\d?\d):(\d\d)')

# %%
# extract the entire time, the hours, the minutes, and the period
df['text'].str.extractall(r'((\d?\d):(\d\d) ?([ap]m))')
# Out:
#                 0   1   2   3
#   match
# 0 0        2:45pm   2  45  pm
# 1 0      11:30 am  11  30  am
# 2 0        7:00pm   7  00  pm
# 3 0      11:15 pm  11  15  pm
# 4 0      08:10 am  08  10  am
#   1       09:00am  09  00  am

# %%
# extract the entire time, the hours, the minutes, and the period with group names
df['text'].str.extractall(r'(?P<time>(?P<hour>\d?\d):(?P<minute>\d\d) ?(?P<period>[ap]m))')
# Out:
#              time hour minute period
#   match
# 0 0        2:45pm    2     45     pm
# 1 0      11:30 am   11     30     am
# 2 0        7:00pm    7     00     pm
# 3 0      11:15 pm   11     15     pm
# 4 0      08:10 am   08     10     am
#   1       09:00am   09     00     am
