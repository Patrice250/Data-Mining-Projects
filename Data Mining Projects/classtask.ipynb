# %%
import pandas as pd

# %%
df= pd.read_excel("financial_sample.xlsx")
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera           NaN      1618.5
# 1  Government  Germany  Carretera           NaN      1321.0
# 2   Midmarket   France  Carretera           NaN      2178.0
# 3   Midmarket  Germany  Carretera           NaN       888.0
# 4   Midmarket   Mexico  Carretera           NaN      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
sa=df[['Manufacturing Price', 'Sale Price']]
sa1=sa.rename(columns={'Manufacturing Price': 'quantity','Sale Price': 'unit_price'})
sa1
# Out:
#      quantity  unit_price
# 0           3          20
# 1           3          20
# 2           3          15
# 3           3          15
# 4           3          15
# ..        ...         ...
# 695       260         300
# 696       260         300
# 697         5           7
# 698        10           7
# 699       250          12
#
# [700 rows x 2 columns]

# %%
# date= df[['Month Number', 'Month Name', 'Year']]
# date1=date.rename(columns={'Month Number':'d_day','Month Name':'d_month','Year':'d_year'})
# date1
date=df[['Month Number', 'Month Name', 'Year']]
date1=date.rename(columns={'Month Number': 'd_day','Month Name': 'd_month','Year':'d_year'})
date1
# Out:
#      d_day   d_month  d_year
# 0        1   January    2014
# 1        1   January    2014
# 2        6      June    2014
# 3        6      June    2014
# 4        6      June    2014
# ..     ...       ...     ...
# 695      3     March    2014
# 696     10   October    2014
# 697      2  February    2014
# 698      4     April    2014
# 699      5       May    2014
#
# [700 rows x 3 columns]

# %%
df1 = pd.read_excel("Electric_Vehicle_Population_Data.xlsx")
df1.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
# product= df1[['Electric Vehicle Type', 'Model']]
# product1=product.rename(columns={'Electric Vehicle Type': 'Product_Name','Model': 'Category'})
# product1

# %%
customer=df[['Segment', 'Country']]
customer1=customer.rename(columns={'Segment':'customer_name','Country':'city'})
customer1
# Out:
#         customer_name                      city
# 0          Government                    Canada
# 1          Government                   Germany
# 2           Midmarket                    France
# 3           Midmarket                   Germany
# 4           Midmarket                    Mexico
# ..                ...                       ...
# 695    Small Business                    France
# 696    Small Business                    Mexico
# 697        Government                    Mexico
# 698        Government                    Canada
# 699  Channel Partners  United States of America
#
# [700 rows x 2 columns]

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector 
mydb=mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="sales10"
)

# %%
cursor=mydb.cursor()

# %%
date1=date.fillna('')
date1
# Out:
#      Month Number Month Name  Year
# 0               1    January  2014
# 1               1    January  2014
# 2               6       June  2014
# 3               6       June  2014
# 4               6       June  2014
# ..            ...        ...   ...
# 695             3      March  2014
# 696            10    October  2014
# 697             2   February  2014
# 698             4      April  2014
# 699             5        May  2014
#
# [700 rows x 3 columns]

# %%
datea=date.dropna()
datea
# Out:
#      Month Number Month Name  Year
# 0               1    January  2014
# 1               1    January  2014
# 2               6       June  2014
# 3               6       June  2014
# 4               6       June  2014
# ..            ...        ...   ...
# 695             3      March  2014
# 696            10    October  2014
# 697             2   February  2014
# 698             4      April  2014
# 699             5        May  2014
#
# [700 rows x 3 columns]

# %%
insert_query = f"INSERT INTO customer_tb ({','.join(customer1.columns)}) VALUES ({','.join(['%s']*len(customer1.columns))})"
    
for _, row in customer1.iterrows():
    values = tuple(row)
    cursor.execute(insert_query, values)
    
mydb.commit()

# %%
insert_query = f"INSERT INTO date_tb ({','.join(date1.columns)}) VALUES ({','.join(['%s']*len(date1.columns))})"
    
for _, row in date1.iterrows():
    values = tuple(row)
    cursor.execute(insert_query, values)
    
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:755, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     754         query = query.encode("utf-8")
# --> 755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#     758         buffered=buffered,
#     759         raw_as_string=raw_as_string,
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near 'Number,Month Name,Year) VALUES (1,'January',2014)' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
insert_query = f"INSERT INTO product_tb ({','.join(product1.columns)}) VALUES ({','.join(['%s']*len(product1.columns))})"
    
for _, row in prodact1.iterrows():
    values = tuple(row)
    cursor.execute(insert_query, values)
    
mydb.commit()

# %%
insert_query = f"INSERT INTO sale_tb ({','.join(sa1.columns)}) VALUES ({','.join(['%s']*len(sa1.columns))})"
    
for _, row in sa1.iterrows():
    values = tuple(row)
    cursor.execute(insert_query, values)
    
mydb.commit()
